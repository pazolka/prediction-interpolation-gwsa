# %% [markdown]
# # 5. Grid-to-point CNN model with Kriging interpolation
#
# 2-step model: Predict points with a grid-to-point CNN model and interpolate spatially with Ordinary Kriging

# %%
import numpy as np
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
import xarray as xr
import pandas as pd
from pyproj import Transformer
import skgstat as skg
from utils.metrics import *

from tensorflow.keras import metrics
from livelossplot.inputs.keras import PlotLossesCallback
from models.grid_to_point import cnn
# Out:
# 2025-11-14 17:58:24.954177: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-14 17:58:24.976363: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
root_path = './data/Bangladesh'
outputs_path = f'{root_path}/outputs'
img_input_path = f"{root_path}/inputs/processed/image_%s.npy"

lag = 5
fill_value = -1

proj_system = "EPSG:32646"

# %%
bgd_shp = gpd.read_file(f'{root_path}/BGD_shp/vb025yv7599.shp')
info_file = pd.read_csv(f'{root_path}/target/well_info.csv')
ndvi_da = xr.open_dataset(f'{root_path}/inputs/NDVI_M_2002_2017_BGD_025.nc4')['NDVI']

# %%
cv_setup = np.load(f'{root_path}/cv_setup.npy', allow_pickle=True).item()
train_ids = cv_setup['train_ids']
holdout_ids = cv_setup['holdout_ids']
tr_idxs = cv_setup['tr_idxs']
test_idxs = cv_setup['test_idxs']
seed = cv_setup['seed']

tf.random.set_seed(seed)

# %%
filled_ts = pd.read_csv(f"{root_path}/target/filtered_filled_missForest_gws_ts_data_1961_2019.csv", parse_dates=['Date'], index_col='Date')
filled_ts = filled_ts['2002-04-01':'2017-05-31'].dropna(axis=1, how='any')
filled_ts_gwsa = filled_ts - filled_ts['2004-01-01':'2009-12-31'].mean()

df_train = filled_ts_gwsa[train_ids].iloc[(lag-1):]

# %%
coords_train = np.array([ info_file[info_file['SegmentID'] == well][['Latitude', 'Longitude']].values[0] for well in train_ids ])
# project the coordinates
transformer = Transformer.from_crs("EPSG:4326", proj_system, always_xy=True)
projected_coords = np.array([
    transformer.transform(lon, lat) for lat, lon in coords_train
])
coords_km = projected_coords / 1000

# %%
grid_lon = ndvi_da.lon.values
grid_lat = ndvi_da.lat.values

lon_mesh, lat_mesh = np.meshgrid(grid_lon, grid_lat)

# Project the entire grid
x_mesh, y_mesh = transformer.transform(lon_mesh, lat_mesh)
grid_x = x_mesh / 1000
grid_y = y_mesh / 1000

# %%
cnn(24,24,5, df_train.shape[1]).summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 24, 24, 5)]       0
#
#  conv2d (Conv2D)             (None, 22, 22, 32)        1472
#
#  max_pooling2d (MaxPooling2  (None, 11, 11, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 9, 9, 64)          18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 4, 4, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense (Dense)               (None, 747)               765675
#
# =================================================================
# Total params: 785643 (3.00 MB)
# Trainable params: 785643 (3.00 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
def interpolate(V, x_mesh, y_mesh, time):
    ok = skg.OrdinaryKriging(V, min_points=2, max_points=30, mode='exact')
    field = ok.transform(x_mesh.flatten(), y_mesh.flatten()).reshape(x_mesh.shape)
    return field

for k, (tr_idx, val_test_idx) in enumerate(zip(tr_idxs, test_idxs)):
    model = cnn(24,24,5, df_train.shape[1])
    val_idx, tes_idx = val_test_idx[:int(len(val_test_idx)/2)], val_test_idx[int(len(val_test_idx)/2):]

    y_fold_tr = df_train.iloc[tr_idx].to_numpy()
    y_fold_val = df_train.iloc[val_idx].to_numpy()

    ## TODO: check global scaling
    y_min, y_max = np.min(y_fold_tr, axis=0)[np.newaxis, :], np.max(y_fold_tr, axis=0)[np.newaxis, :]
    Y_tr = (y_fold_tr - y_min)/(y_max - y_min)
    Y_val = (y_fold_val - y_min)/(y_max - y_min)

    input_train = np.array([np.load(img_input_path % i) for i in (tr_idx + (lag-1))])
    input_val = np.array([np.load(img_input_path % i) for i in (val_idx + (lag-1))])
    input_test = np.array([np.load(img_input_path % i) for i in (tes_idx + (lag-1))])
    input_train[input_train == -1] = np.nan
    input_val[input_val == -1] = np.nan
    input_test[input_test == -1] = np.nan


    x_min, x_max = np.nanmin(input_train, axis=(0,1,2)), np.nanmax(input_train, axis=(0,1,2))
    X_tr = (input_train - x_min) / (x_max - x_min)
    X_val = (input_val - x_min) / (x_max - x_min)
    X_test = (input_test - x_min) / (x_max - x_min)
    X_tr[np.isnan(X_tr)] = -1
    X_val[np.isnan(X_val)] = -1
    X_test[np.isnan(X_test)] = -1

    model.compile(optimizer='adam', loss='mean_squared_error', metrics = [ metrics.R2Score() ])
    history = model.fit(X_tr,
          Y_tr,
          batch_size=16,
          epochs=60,
          validation_data=[X_val, Y_val],
          #callbacks=[
              # ModelCheckpoint(filepath=f'g2p_{imput_method}_{target_var}.weights.hdf5',
              #                 save_best_only=True),
          #    PlotLossesCallback()],
          verbose=0)
    
    pred_target = model.predict([
        np.concatenate((X_tr, X_val, X_test), axis=0)],
        batch_size=5)

    rescaled_pred_target = pred_target * (y_max - y_min) + y_min

    np.save(f'{outputs_path}/g2p_CNN/g2p_cnn_point_gwsa_fold_{k}.npy', rescaled_pred_target)
    total_time_len = len(tr_idx) + len(val_test_idx)
    kriged_target = np.zeros((total_time_len, *ndvi_da[0].shape))
    variances = np.zeros((total_time_len, *ndvi_da[0].shape))
    
    variograms = []
    
    for t in range(0, rescaled_pred_target.shape[0]):
        print(f'Interpolating t= {t}')
        variogram = skg.Variogram(coords_km, rescaled_pred_target[t], model='spherical', maxlag='median', use_nugget=True, normalize=False,
                                  fit_method='trf',  # Trust Region Reflective fitting
                                  fit_kwargs={'initial': [0.0013, 0.0025, 200]})
        variograms.append(variogram)
        kriged_target[t] = interpolate(variogram, grid_x, grid_y, df_train.iloc[t].index)

    dates = df_train.index[:(tes_idx[-1]+1)].to_numpy()
    kriged_target_da = xr.DataArray(kriged_target, coords={'time': dates, 'lat': np.round(grid_y[:, 0] * 1000, 2), 'lon': np.round(grid_x[0, :] * 1000, 2)}, dims=['time', 'lat', 'lon'])

    # clip to Bangladesh
    kriged_target_da = kriged_target_da.rio.set_spatial_dims(x_dim='lon', y_dim='lat', inplace=True)
    kriged_target_da = kriged_target_da.rio.write_crs(proj_system, inplace=True)
    kriged_target_da_wgs = kriged_target_da.rio.reproject("EPSG:4326", nodata=np.nan)
    kriged_target_da_wgs = kriged_target_da_wgs.rename({'x': 'lon', 'y': 'lat'})
    kriged_target_da_wgs = kriged_target_da_wgs.rio.clip(bgd_shp.geometry.values, bgd_shp.crs, all_touched=True)
    
    kriged_target_da_wgs.to_dataset(name='gwsa').to_netcdf(f'{outputs_path}/g2p_CNN_Kriging/g2p_cnn_krig_filled_gwsa_fold_{k}.nc4')
# Out:
# 7/7 [==============================] - 0s 1ms/step
# Interpolating t= 0
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 1
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 2
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 3
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 4
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 5
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 6
# Warning: for 33 locations, not enough neighbors were found within the range.
# Interpolating t= 7
# Warning: for 59 locations, not enough neighbors were found within the range.
# Interpolating t= 8
# Warning: for 66 locations, not enough neighbors were found within the range.
# Interpolating t= 9
# Warning: for 101 locations, not enough neighbors were found within the range.
# Interpolating t= 10
# Warning: for 185 locations, not enough neighbors were found within the range.
# Interpolating t= 11
# Warning: for 69 locations, not enough neighbors were found within the range.
# Interpolating t= 12
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 13
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 14
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 15
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 16
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 17
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 18
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 19
# Warning: for 51 locations, not enough neighbors were found within the range.
# Interpolating t= 20
# Warning: for 90 locations, not enough neighbors were found within the range.
# Interpolating t= 21
# Warning: for 133 locations, not enough neighbors were found within the range.
# Interpolating t= 22
# Warning: for 208 locations, not enough neighbors were found within the range.
# Interpolating t= 23
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 24
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 25
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 26
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 27
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 28
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 29
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 30
# Warning: for 30 locations, not enough neighbors were found within the range.
# Interpolating t= 31
# Warning: for 55 locations, not enough neighbors were found within the range.
# Interpolating t= 32
# Warning: for 91 locations, not enough neighbors were found within the range.
# Interpolating t= 33
# Warning: for 113 locations, not enough neighbors were found within the range.
# 10/10 [==============================] - 0s 1ms/step
# Interpolating t= 0
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 1
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 2
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 3
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 4
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 5
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 6
# Warning: for 36 locations, not enough neighbors were found within the range.
# Interpolating t= 7
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 8
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 9
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 10
# Warning: for 46 locations, not enough neighbors were found within the range.
# Interpolating t= 11
# Warning: for 76 locations, not enough neighbors were found within the range.
# Interpolating t= 12
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 13
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 14
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 15
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 16
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 17
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 18
# Warning: for 38 locations, not enough neighbors were found within the range.
# Interpolating t= 19
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 20
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 21
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 22
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 23
# Warning: for 65 locations, not enough neighbors were found within the range.
# Interpolating t= 24
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 25
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 26
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 27
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 28
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 29
# Warning: for 29 locations, not enough neighbors were found within the range.
# Interpolating t= 30
# Warning: for 30 locations, not enough neighbors were found within the range.
# Interpolating t= 31
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 32
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 33
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 34
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 35
# Warning: for 109 locations, not enough neighbors were found within the range.
# Interpolating t= 36
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 37
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 38
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 39
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 40
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 41
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 42
# Warning: for 30 locations, not enough neighbors were found within the range.
# Interpolating t= 43
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 44
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 45
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 46
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 47
# Warning: for 48 locations, not enough neighbors were found within the range.
# Interpolating t= 48
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 49
# Warning: for 28 locations, not enough neighbors were found within the range.
# 14/14 [==============================] - 0s 1ms/step
# Interpolating t= 0
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 1
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 2
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 3
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 4
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 5
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 6
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 7
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 8
# Warning: for 29 locations, not enough neighbors were found within the range.
# Interpolating t= 9
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 10
# Warning: for 48 locations, not enough neighbors were found within the range.
# Interpolating t= 11
# Warning: for 76 locations, not enough neighbors were found within the range.
# Interpolating t= 12
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 13
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 14
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 15
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 16
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 17
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 18
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 19
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 20
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 21
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 22
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 23
# Warning: for 66 locations, not enough neighbors were found within the range.
# Interpolating t= 24
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 25
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 26
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 27
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 28
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 29
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 30
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 31
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 32
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 33
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 34
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 35
# Warning: for 81 locations, not enough neighbors were found within the range.
# Interpolating t= 36
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 37
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 38
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 39
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 40
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 41
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 42
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 43
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 44
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 45
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 46
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 47
# Warning: for 76 locations, not enough neighbors were found within the range.
# Interpolating t= 48
# Warning: for 68 locations, not enough neighbors were found within the range.
# Interpolating t= 49
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 50
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 51
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 52
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 53
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 54
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 55
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 56
# Warning: for 30 locations, not enough neighbors were found within the range.
# Interpolating t= 57
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 58
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 59
# Warning: for 44 locations, not enough neighbors were found within the range.
# Interpolating t= 60
# Warning: for 75 locations, not enough neighbors were found within the range.
# Interpolating t= 61
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 62
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 63
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 64
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 65
# Warning: for 28 locations, not enough neighbors were found within the range.
# 17/17 [==============================] - 0s 1ms/step
# Interpolating t= 0
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 1
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 2
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 3
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 4
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 5
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 6
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 7
# Warning: for 30 locations, not enough neighbors were found within the range.
# Interpolating t= 8
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 9
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 10
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 11
# Warning: for 87 locations, not enough neighbors were found within the range.
# Interpolating t= 12
# Warning: for 37 locations, not enough neighbors were found within the range.
# Interpolating t= 13
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 14
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 15
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 16
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 17
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 18
# Warning: for 30 locations, not enough neighbors were found within the range.
# Interpolating t= 19
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 20
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 21
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 22
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 23
# Warning: for 73 locations, not enough neighbors were found within the range.
# Interpolating t= 24
# Warning: for 48 locations, not enough neighbors were found within the range.
# Interpolating t= 25
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 26
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 27
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 28
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 29
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 30
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 31
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 32
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 33
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 34
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 35
# Warning: for 78 locations, not enough neighbors were found within the range.
# Interpolating t= 36
# Warning: for 47 locations, not enough neighbors were found within the range.
# Interpolating t= 37
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 38
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 39
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 40
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 41
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 42
# Warning: for 35 locations, not enough neighbors were found within the range.
# Interpolating t= 43
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 44
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 45
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 46
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 47
# Warning: for 89 locations, not enough neighbors were found within the range.
# Interpolating t= 48
# Warning: for 76 locations, not enough neighbors were found within the range.
# Interpolating t= 49
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 50
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 51
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 52
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 53
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 54
# Warning: for 36 locations, not enough neighbors were found within the range.
# Interpolating t= 55
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 56
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 57
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 58
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 59
# Warning: for 82 locations, not enough neighbors were found within the range.
# Interpolating t= 60
# Warning: for 72 locations, not enough neighbors were found within the range.
# Interpolating t= 61
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 62
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 63
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 64
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 65
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 66
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 67
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 68
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 69
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 70
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 71
# Warning: for 81 locations, not enough neighbors were found within the range.
# Interpolating t= 72
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 73
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 74
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 75
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 76
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 77
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 78
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 79
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 80
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 81
# Warning: for 28 locations, not enough neighbors were found within the range.
# 20/20 [==============================] - 0s 1ms/step
# Interpolating t= 0
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 1
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 2
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 3
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 4
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 5
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 6
# Warning: for 40 locations, not enough neighbors were found within the range.
# Interpolating t= 7
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 8
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 9
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 10
# Warning: for 38 locations, not enough neighbors were found within the range.
# Interpolating t= 11
# Warning: for 76 locations, not enough neighbors were found within the range.
# Interpolating t= 12
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 13
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 14
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 15
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 16
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 17
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 18
# Warning: for 36 locations, not enough neighbors were found within the range.
# Interpolating t= 19
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 20
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 21
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 22
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 23
# Warning: for 71 locations, not enough neighbors were found within the range.
# Interpolating t= 24
# Warning: for 33 locations, not enough neighbors were found within the range.
# Interpolating t= 25
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 26
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 27
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 28
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 29
# Warning: for 37 locations, not enough neighbors were found within the range.
# Interpolating t= 30
# Warning: for 38 locations, not enough neighbors were found within the range.
# Interpolating t= 31
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 32
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 33
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 34
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 35
# Warning: for 88 locations, not enough neighbors were found within the range.
# Interpolating t= 36
# Warning: for 30 locations, not enough neighbors were found within the range.
# Interpolating t= 37
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 38
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 39
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 40
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 41
# Warning: for 36 locations, not enough neighbors were found within the range.
# Interpolating t= 42
# Warning: for 38 locations, not enough neighbors were found within the range.
# Interpolating t= 43
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 44
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 45
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 46
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 47
# Warning: for 81 locations, not enough neighbors were found within the range.
# Interpolating t= 48
# Warning: for 63 locations, not enough neighbors were found within the range.
# Interpolating t= 49
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 50
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 51
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 52
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 53
# Warning: for 38 locations, not enough neighbors were found within the range.
# Interpolating t= 54
# Warning: for 46 locations, not enough neighbors were found within the range.
# Interpolating t= 55
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 56
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 57
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 58
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 59
# Warning: for 69 locations, not enough neighbors were found within the range.
# Interpolating t= 60
# Warning: for 48 locations, not enough neighbors were found within the range.
# Interpolating t= 61
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 62
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 63
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 64
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 65
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 66
# Warning: for 43 locations, not enough neighbors were found within the range.
# Interpolating t= 67
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 68
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 69
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 70
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 71
# Warning: for 69 locations, not enough neighbors were found within the range.
# Interpolating t= 72
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 73
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 74
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 75
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 76
# Warning: for 42 locations, not enough neighbors were found within the range.
# Interpolating t= 77
# Warning: for 44 locations, not enough neighbors were found within the range.
# Interpolating t= 78
# Warning: for 41 locations, not enough neighbors were found within the range.
# Interpolating t= 79
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 80
# Warning: for 30 locations, not enough neighbors were found within the range.
# Interpolating t= 81
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 82
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 83
# Warning: for 57 locations, not enough neighbors were found within the range.
# Interpolating t= 84
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 85
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 86
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 87
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 88
# Warning: for 52 locations, not enough neighbors were found within the range.
# Interpolating t= 89
# Warning: for 46 locations, not enough neighbors were found within the range.
# Interpolating t= 90
# Warning: for 41 locations, not enough neighbors were found within the range.
# Interpolating t= 91
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 92
# Warning: for 30 locations, not enough neighbors were found within the range.
# Interpolating t= 93
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 94
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 95
# Warning: for 88 locations, not enough neighbors were found within the range.
# Interpolating t= 96
# Warning: for 67 locations, not enough neighbors were found within the range.
# Interpolating t= 97
# Warning: for 28 locations, not enough neighbors were found within the range.
# 23/23 [==============================] - 0s 1ms/step
# Interpolating t= 0
# Warning: for 49 locations, not enough neighbors were found within the range.
# Interpolating t= 1
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 2
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 3
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 4
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 5
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 6
# Warning: for 38 locations, not enough neighbors were found within the range.
# Interpolating t= 7
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 8
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 9
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 10
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 11
# Warning: for 88 locations, not enough neighbors were found within the range.
# Interpolating t= 12
# Warning: for 39 locations, not enough neighbors were found within the range.
# Interpolating t= 13
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 14
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 15
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 16
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 17
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 18
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 19
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 20
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 21
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 22
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 23
# Warning: for 74 locations, not enough neighbors were found within the range.
# Interpolating t= 24
# Warning: for 59 locations, not enough neighbors were found within the range.
# Interpolating t= 25
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 26
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 27
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 28
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 29
# Warning: for 38 locations, not enough neighbors were found within the range.
# Interpolating t= 30
# Warning: for 35 locations, not enough neighbors were found within the range.
# Interpolating t= 31
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 32
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 33
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 34
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 35
# Warning: for 48 locations, not enough neighbors were found within the range.
# Interpolating t= 36
# Warning: for 63 locations, not enough neighbors were found within the range.
# Interpolating t= 37
# Warning: for 30 locations, not enough neighbors were found within the range.
# Interpolating t= 38
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 39
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 40
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 41
# Warning: for 47 locations, not enough neighbors were found within the range.
# Interpolating t= 42
# Warning: for 48 locations, not enough neighbors were found within the range.
# Interpolating t= 43
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 44
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 45
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 46
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 47
# Warning: for 57 locations, not enough neighbors were found within the range.
# Interpolating t= 48
# Warning: for 48 locations, not enough neighbors were found within the range.
# Interpolating t= 49
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 50
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 51
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 52
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 53
# Warning: for 63 locations, not enough neighbors were found within the range.
# Interpolating t= 54
# Warning: for 38 locations, not enough neighbors were found within the range.
# Interpolating t= 55
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 56
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 57
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 58
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 59
# Warning: for 70 locations, not enough neighbors were found within the range.
# Interpolating t= 60
# Warning: for 65 locations, not enough neighbors were found within the range.
# Interpolating t= 61
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 62
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 63
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 64
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 65
# Warning: for 59 locations, not enough neighbors were found within the range.
# Interpolating t= 66
# Warning: for 49 locations, not enough neighbors were found within the range.
# Interpolating t= 67
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 68
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 69
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 70
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 71
# Warning: for 81 locations, not enough neighbors were found within the range.
# Interpolating t= 72
# Warning: for 38 locations, not enough neighbors were found within the range.
# Interpolating t= 73
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 74
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 75
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 76
# Warning: for 208 locations, not enough neighbors were found within the range.
# Interpolating t= 77
# Warning: for 70 locations, not enough neighbors were found within the range.
# Interpolating t= 78
# Warning: for 30 locations, not enough neighbors were found within the range.
# Interpolating t= 79
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 80
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 81
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 82
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 83
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 84
# Warning: for 65 locations, not enough neighbors were found within the range.
# Interpolating t= 85
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 86
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 87
# Warning: for 70 locations, not enough neighbors were found within the range.
# Interpolating t= 88
# Warning: for 77 locations, not enough neighbors were found within the range.
# Interpolating t= 89
# Warning: for 57 locations, not enough neighbors were found within the range.
# Interpolating t= 90
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 91
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 92
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 93
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 94
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 95
# Warning: for 44 locations, not enough neighbors were found within the range.
# Interpolating t= 96
# Warning: for 43 locations, not enough neighbors were found within the range.
# Interpolating t= 97
# Warning: for 38 locations, not enough neighbors were found within the range.
# Interpolating t= 98
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 99
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 100
# Warning: for 29 locations, not enough neighbors were found within the range.
# Interpolating t= 101
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 102
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 103
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 104
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 105
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 106
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 107
# Warning: for 37 locations, not enough neighbors were found within the range.
# Interpolating t= 108
# Warning: for 68 locations, not enough neighbors were found within the range.
# Interpolating t= 109
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 110
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 111
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 112
# Warning: for 86 locations, not enough neighbors were found within the range.
# Interpolating t= 113
# Warning: for 28 locations, not enough neighbors were found within the range.
# 26/26 [==============================] - 0s 2ms/step
# Interpolating t= 0
# Warning: for 40 locations, not enough neighbors were found within the range.
# Interpolating t= 1
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 2
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 3
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 4
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 5
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 6
# Warning: for 40 locations, not enough neighbors were found within the range.
# Interpolating t= 7
# Warning: for 36 locations, not enough neighbors were found within the range.
# Interpolating t= 8
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 9
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 10
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 11
# Warning: for 76 locations, not enough neighbors were found within the range.
# Interpolating t= 12
# Warning: for 39 locations, not enough neighbors were found within the range.
# Interpolating t= 13
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 14
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 15
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 16
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 17
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 18
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 19
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 20
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 21
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 22
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 23
# Warning: for 75 locations, not enough neighbors were found within the range.
# Interpolating t= 24
# Warning: for 55 locations, not enough neighbors were found within the range.
# Interpolating t= 25
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 26
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 27
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 28
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 29
# Warning: for 49 locations, not enough neighbors were found within the range.
# Interpolating t= 30
# Warning: for 45 locations, not enough neighbors were found within the range.
# Interpolating t= 31
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 32
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 33
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 34
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 35
# Warning: for 63 locations, not enough neighbors were found within the range.
# Interpolating t= 36
# Warning: for 71 locations, not enough neighbors were found within the range.
# Interpolating t= 37
# Warning: for 44 locations, not enough neighbors were found within the range.
# Interpolating t= 38
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 39
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 40
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 41
# Warning: for 65 locations, not enough neighbors were found within the range.
# Interpolating t= 42
# Warning: for 58 locations, not enough neighbors were found within the range.
# Interpolating t= 43
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 44
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 45
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 46
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 47
# ...
# Interpolating t= 14
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 15
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 16
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 17
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 18
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 19
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 20
# Warning: for 29 locations, not enough neighbors were found within the range.
# Interpolating t= 21
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 22
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 23
# Warning: for 49 locations, not enough neighbors were found within the range.
# Interpolating t= 24
# Warning: for 34 locations, not enough neighbors were found within the range.
# Interpolating t= 25
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 26
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 27
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 28
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 29
# Warning: for 59 locations, not enough neighbors were found within the range.
# Interpolating t= 30
# Warning: for 56 locations, not enough neighbors were found within the range.
# Interpolating t= 31
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 32
# Warning: for 38 locations, not enough neighbors were found within the range.
# Interpolating t= 33
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 34
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 35
# Warning: for 65 locations, not enough neighbors were found within the range.
# Interpolating t= 36
# Warning: for 48 locations, not enough neighbors were found within the range.
# Interpolating t= 37
# Warning: for 36 locations, not enough neighbors were found within the range.
# Interpolating t= 38
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 39
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 40
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 41
# Warning: for 88 locations, not enough neighbors were found within the range.
# Interpolating t= 42
# Warning: for 67 locations, not enough neighbors were found within the range.
# Interpolating t= 43
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 44
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 45
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 46
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 47
# Warning: for 42 locations, not enough neighbors were found within the range.
# Interpolating t= 48
# Warning: for 41 locations, not enough neighbors were found within the range.
# Interpolating t= 49
# Warning: for 30 locations, not enough neighbors were found within the range.
# Interpolating t= 50
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 51
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 52
# Warning: for 74 locations, not enough neighbors were found within the range.
# Interpolating t= 53
# Warning: for 75 locations, not enough neighbors were found within the range.
# Interpolating t= 54
# Warning: for 48 locations, not enough neighbors were found within the range.
# Interpolating t= 55
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 56
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 57
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 58
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 59
# Warning: for 49 locations, not enough neighbors were found within the range.
# Interpolating t= 60
# Warning: for 41 locations, not enough neighbors were found within the range.
# Interpolating t= 61
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 62
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 63
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 64
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 65
# Warning: for 103 locations, not enough neighbors were found within the range.
# Interpolating t= 66
# Warning: for 49 locations, not enough neighbors were found within the range.
# Interpolating t= 67
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 68
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 69
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 70
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 71
# Warning: for 63 locations, not enough neighbors were found within the range.
# Interpolating t= 72
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 73
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 74
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 75
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 76
# Warning: for 36 locations, not enough neighbors were found within the range.
# Interpolating t= 77
# Warning: for 65 locations, not enough neighbors were found within the range.
# Interpolating t= 78
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 79
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 80
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 81
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 82
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 83
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 84
# Warning: for 49 locations, not enough neighbors were found within the range.
# Interpolating t= 85
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 86
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 87
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 88
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 89
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 90
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 91
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 92
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 93
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 94
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 95
# Warning: for 30 locations, not enough neighbors were found within the range.
# Interpolating t= 96
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 97
# Warning: for 36 locations, not enough neighbors were found within the range.
# Interpolating t= 98
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 99
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 100
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 101
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 102
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 103
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 104
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 105
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 106
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 107
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 108
# Warning: for 30 locations, not enough neighbors were found within the range.
# Interpolating t= 109
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 110
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 111
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 112
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 113
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 114
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 115
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 116
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 117
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 118
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 119
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 120
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 121
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 122
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 123
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 124
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 125
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 126
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 127
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 128
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 129
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 130
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 131
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 132
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 133
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 134
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 135
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 136
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 137
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 138
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 139
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 140
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 141
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 142
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 143
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 144
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 145
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 146
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 147
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 148
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 149
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 150
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 151
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 152
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 153
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 154
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 155
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 156
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 157
# Warning: for 35 locations, not enough neighbors were found within the range.
# Interpolating t= 158
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 159
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 160
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 161
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 162
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 163
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 164
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 165
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 166
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 167
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 168
# Warning: for 36 locations, not enough neighbors were found within the range.
# Interpolating t= 169
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 170
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 171
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 172
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 173
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 174
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 175
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 176
# Warning: for 28 locations, not enough neighbors were found within the range.
# Interpolating t= 177
# Warning: for 28 locations, not enough neighbors were found within the range.

# %%
dtype = [('id', 'U10'), ('value1', 'f4'), ('value2', 'f4')]
tmp = np.empty(len(coords_train), dtype=dtype)
for i, (lat, lon) in enumerate(coords_train):
    tmp[i] = (df_train.columns[i], lat, lon)

np.save(f'{root_path}/target/predicted_point_coords_ids.npy', tmp)

# %%
fig, ax = plt.subplots(figsize=(8, 6))
kriged_target_da_wgs[0].plot(ax = ax, cmap='RdBu', vmin=-0.1, vmax=0.1)
bgd_shp.boundary.plot(color='gray', linewidth=0.5, ax=ax)
# Out:
# <Axes: title={'center': 'time = 2002-08-15, spatial_ref = 0'}, xlabel='longitude [degrees_east]', ylabel='latitude [degrees_north]'>
