# %% [markdown]
# # 2. Full Bangladesh dataset preprocessing
#
#  Acceptance criteria for Bangladesh dataset
#
# - if there is a continuous gap of 3 years -> split
#
# - any sudden shifts indicating changes to the well location and depth -> split
#
#
# _(inludes manual preprocessing steps supported by an expert examination of time-series plots)_

# %%
import geopandas as gpd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import rioxarray as rxr
import geopandas as gpd

import utils.outliers_helpers as ohp
import utils.changepoint_helpers as chp
from matplotlib.backends.backend_pdf import PdfPages

# %%
MIN_VALID_POINTS_PER_SEGMENT = 60 # Minimum non-NaN points for a segment to be processed
GAP_THRESHOLD_MONTHS = 36
root_path = './data/Bangladesh/'

# %% [markdown]
# #### 1. Read files

# %%
info_file = pd.read_csv(f'{root_path}/target/well_info.csv')
info_file = gpd.GeoDataFrame(
    info_file, geometry=gpd.points_from_xy(info_file.Longitude, info_file.Latitude), crs="EPSG:4326"
)

ts_file = pd.read_csv(f'{root_path}/target/raw_data.csv')

storage_co_da = rxr.open_rasterio(f"{root_path}/BGD_storage_coefficient.tif")

# %%
# filter the relevant dates
ts_file['Date'] = pd.to_datetime(ts_file['Date'], format='%d/%m/%Y')
# Correct years that are mistakenly in the 2000s
ts_file['Date'] = ts_file['Date'].apply(lambda x: x.replace(year=x.year - 100) if x.year > 2025 else x)

ts_file = ts_file.set_index('Date')

# %%
ts_file
# Out:
#             SY101  FA062  RA-63  DI077  BO033  PT005  DI058  RAJ-A-4  FA012  \
# Date
# 1961-01-15    NaN    NaN    NaN    NaN    NaN    NaN    NaN      NaN    NaN
# 1961-02-15    NaN    NaN    NaN    NaN    NaN    NaN    NaN      NaN    NaN
# 1961-03-15    NaN    NaN    NaN    NaN    NaN    NaN    NaN      NaN    NaN
# 1961-04-15    NaN    NaN    NaN    NaN    NaN    NaN    NaN      NaN    NaN
# 1961-05-15    NaN    NaN    NaN    NaN    NaN    NaN    NaN      NaN    NaN
# ...           ...    ...    ...    ...    ...    ...    ...      ...    ...
# 2019-08-15    NaN    NaN    NaN    NaN    NaN    NaN    NaN      NaN    NaN
# 2019-09-15    NaN    NaN    NaN    NaN    NaN    NaN    NaN      NaN    NaN
# 2019-10-15    NaN    NaN    NaN    NaN    NaN    NaN    NaN      NaN    NaN
# 2019-11-15    NaN    NaN    NaN    NaN    NaN    NaN    NaN      NaN    NaN
# 2019-12-15    NaN    NaN    NaN    NaN    NaN    NaN    NaN      NaN    NaN
#
#             CT017  ...  DI068S  MY041  KTS009  PAS02  RJS024  RJS026  SY096  \
# Date               ...
# 1961-01-15    NaN  ...     NaN    NaN     NaN    NaN     NaN     NaN    NaN
# 1961-02-15    NaN  ...     NaN    NaN     NaN    NaN     NaN     NaN    NaN
# 1961-03-15    NaN  ...     NaN    NaN     NaN    NaN     NaN     NaN    NaN
# 1961-04-15    NaN  ...     NaN    NaN     NaN    NaN     NaN     NaN    NaN
# 1961-05-15    NaN  ...     NaN    NaN     NaN    NaN     NaN     NaN    NaN
# ...           ...  ...     ...    ...     ...    ...     ...     ...    ...
# 2019-08-15    NaN  ...     NaN    NaN     NaN    NaN     NaN     NaN    NaN
# 2019-09-15    NaN  ...     NaN    NaN     NaN    NaN     NaN     NaN    NaN
# 2019-10-15    NaN  ...     NaN    NaN     NaN    NaN     NaN     NaN    NaN
# 2019-11-15    NaN  ...     NaN    NaN     NaN    NaN     NaN     NaN    NaN
# 2019-12-15    NaN  ...     NaN    NaN     NaN    NaN     NaN     NaN    NaN
#
#             PAS01  RJ083  RJ119
# Date
# 1961-01-15    NaN    NaN    NaN
# 1961-02-15    NaN    NaN    NaN
# 1961-03-15    NaN    NaN    NaN
# 1961-04-15    NaN    NaN    NaN
# 1961-05-15    NaN    NaN    NaN
# ...           ...    ...    ...
# 2019-08-15    NaN    NaN    NaN
# 2019-09-15    NaN    NaN    NaN
# 2019-10-15    NaN    NaN    NaN
# 2019-11-15    NaN    NaN    NaN
# 2019-12-15    NaN    NaN    NaN
#
# [708 rows x 1250 columns]

# %% [markdown]
# #### 2. Preprocess
# outlier detection: remove outliers
#
# large gap detection: split ts
#
# change detection: split ts

# %%
segment_means = {}
outlier_detected = {}
well_changed = {}

ts_file_gws = {}
ts_file_gwl = {}  
ts_file_bgl = {}  

for well in ts_file.columns:
    if well == 'Date': continue

    ts_info = info_file.loc[info_file['OldID'] == well].head(1)

    # skip wells that have no corresponding information
    if ts_info.empty or np.isnan(ts_info.Longitude).item():
        continue

    # skip wells that have extremely unreliable/messy time series (after visual inspection)
    # some of them could have been impacted by flooding that damaged the measuring equipment 
    if well in ['CT050', 'BA026', 'MY081']:
        continue

    # --- Gap Detection and Splitting ---
    well_series_raw = ts_file[well].copy()
    well_series_raw = well_series_raw - ts_info.ParaHeight.item() + ts_info.RefLevel.item()
    valid_points = well_series_raw.dropna()

    if valid_points.empty:
        print(f"Well {well} has no valid data points. Skipping.")
        continue

    valid_indices = valid_points.index
    segments_to_process = []

    if len(valid_indices) > 1:
        # Calculate month differences between consecutive valid points
        month_number = (valid_indices.year * 12 + valid_indices.month).to_series(index=valid_indices)
        month_diff = month_number.diff()

        # Find the start dates of segments following a large gap
        split_points_start_dates = valid_indices[month_diff > GAP_THRESHOLD_MONTHS]

        # Define segment boundaries
        current_start_date = valid_indices.min() # Start from the first valid point
        for split_date in split_points_start_dates:
            # Define the end date for the current segment (inclusive)
            # Find the last valid index strictly before the split_date
            segment_end_date = valid_indices[valid_indices < split_date].max() + pd.DateOffset(months=1)
            segment = well_series_raw.loc[current_start_date:segment_end_date]
            if not segment.dropna().empty: # Ensure segment has data
                 segments_to_process.append(segment)
            current_start_date = split_date # Next segment starts at the split date

        # Add the final segment (from the last split point or the beginning to the end)
        last_segment = well_series_raw.loc[current_start_date:valid_indices.max()]
        if not last_segment.dropna().empty:
             segments_to_process.append(last_segment)

    elif len(valid_indices) == 1:
         segments_to_process.append(valid_points) # Only one point, treat as a segment
    else: # Should have been caught by valid_points.empty() check, but for safety
        continue

    # If no gaps were found, segments_to_process will contain the whole series (if valid)
    if not segments_to_process and not valid_points.empty:
         segments_to_process.append(well_series_raw)

    # --- Process Each Segment ---
    segment_count = len(segments_to_process)
    for i, segment in enumerate(segments_to_process):
        segment = segment.copy() # Work on a copy

        # Check for sufficient valid points in the segment
        if segment.dropna().shape[0] < MIN_VALID_POINTS_PER_SEGMENT:
            print(f"Well {well}, Segment {i+1}/{segment_count}: Too few valid points ({segment.dropna().shape[0]}). Skipping segment.")
            if well not in ['RA-36', 'PA012', 'JA012']: # Don't discard data that should be stitched in postprocessing
                continue

        # Determine the column name for the processed segment
        segment_col_name = f"{well}_{i+1}" if segment_count > 1 else well

        # Find storage co for GWS conversion later
        try:
            st_co = storage_co_da.sel(y=ts_info['Latitude'].item(), x=ts_info['Longitude'].item(), method="nearest").item()
            if np.isnan(st_co) or st_co <= 0: # Handle invalid storage coefficient
                 print(f"Warning: Well {well}, Segment {i+1}: Invalid storage coefficient ({st_co}). Skipping segment.")
                 continue
        except Exception as e:
            print(f"Warning: Well {well}, Segment {i+1}: Could not get storage coefficient at coords ({ts_info['Longitude'].item()}, {ts_info['Latitude'].item()}). Error: {e}. Skipping segment.")
            continue
            
        # --- Outlier Detection (on the segment GWL) ---
        segment_cleaned, outlier_found = ohp.remove_outliers(segment.copy())
        outlier_detected[segment_col_name] = outlier_found

        # --- Change Point Detection (on the cleaned segment GWL) ---
        well_changed[segment_col_name] = chp.detect_well_change(segment_cleaned.copy())
        # --- Add Time Series Segments defined by change points ---
        seg_ts, bps = well_changed[segment_col_name]
        if len(bps) > 0:
            start_idx = 0
            for i, bp in enumerate(bps):
                seg_col_name = f'{segment_col_name}_{i}'
                seg_cleaned, _ = ohp.remove_outliers(seg_ts[start_idx:bp].copy())
                if seg_cleaned.dropna().shape[0] < MIN_VALID_POINTS_PER_SEGMENT:
                    start_idx = bp
                    continue
                ts_file_gws[seg_col_name] = seg_cleaned * ( st_co / 100 )
                ts_file_gwl[seg_col_name] = seg_cleaned
                ts_file_bgl[seg_col_name] = ts_file_gwl[seg_col_name] + ts_info.ParaHeight.item() - ts_info.RefLevel.item()
                start_idx = bp
            final_seg_cleaned, _ = ohp.remove_outliers(seg_ts[start_idx:].copy())
            if final_seg_cleaned.dropna().shape[0] < MIN_VALID_POINTS_PER_SEGMENT:
                # I'm stitching these manually later
                if well not in ['SY074', 'MY084', 'BO038']:
                    continue
            ts_file_gws[f'{segment_col_name}_{i+1}'] = final_seg_cleaned * ( st_co / 100 )
            ts_file_gwl[f'{segment_col_name}_{i+1}'] = final_seg_cleaned
            ts_file_bgl[f'{segment_col_name}_{i+1}'] = ts_file_gwl[f'{segment_col_name}_{i+1}'] + ts_info.ParaHeight.item() - ts_info.RefLevel.item()
        else:        
            # --- Store Processed Segment ---
            # Add the processed segment to the results DataFrame, aligning index
            ts_file_gws[segment_col_name] = segment_cleaned * ( st_co / 100 )
            ts_file_gwl[segment_col_name] = segment_cleaned
            ts_file_bgl[segment_col_name] = ts_file_gwl[segment_col_name] + ts_info.ParaHeight.item() - ts_info.RefLevel.item()

ts_file_gws = pd.DataFrame(ts_file_gws, index=ts_file.index)
ts_file_gwl = pd.DataFrame(ts_file_gwl, index=ts_file.index)  
ts_file_bgl = pd.DataFrame(ts_file_bgl, index=ts_file.index)

print("Processing finished.")
print(f"Generated {ts_file_gws.shape[1]} processed time series segments.")
# Out:
# Well RA-36, Segment 2/2: Too few valid points (23). Skipping segment.
# Well JE006, Segment 2/2: Too few valid points (41). Skipping segment.
# Well DH111, Segment 1/2: Too few valid points (19). Skipping segment.
# Well DI040, Segment 1/2: Too few valid points (44). Skipping segment.
# Well PA012, Segment 2/2: Too few valid points (35). Skipping segment.
# Well RJ052, Segment 1/2: Too few valid points (53). Skipping segment.
# Well BA011, Segment 1/2: Too few valid points (40). Skipping segment.
# Well DI046, Segment 1/2: Too few valid points (59). Skipping segment.
# Well KT019, Segment 2/2: Too few valid points (28). Skipping segment.
# Well CM033, Segment 2/2: Too few valid points (2). Skipping segment.
# Well JE021, Segment 1/2: Too few valid points (14). Skipping segment.
# Well TA037, Segment 2/2: Too few valid points (13). Skipping segment.
# Well CT012, Segment 2/2: Too few valid points (1). Skipping segment.
# Well RJ049, Segment 1/2: Too few valid points (41). Skipping segment.
# Well DI068, Segment 1/2: Too few valid points (12). Skipping segment.
# Well CM055, Segment 2/3: Too few valid points (23). Skipping segment.
# Well CM055, Segment 3/3: Too few valid points (1). Skipping segment.
# Well FA053, Segment 2/2: Too few valid points (29). Skipping segment.
# Well BA013, Segment 1/2: Too few valid points (10). Skipping segment.
# Well FA048, Segment 2/2: Too few valid points (30). Skipping segment.
# Well KT038, Segment 2/2: Too few valid points (35). Skipping segment.
# Well JE044, Segment 2/2: Too few valid points (27). Skipping segment.
# Well TA007, Segment 1/2: Too few valid points (37). Skipping segment.
# Well KH002, Segment 2/2: Too few valid points (5). Skipping segment.
# Well CM016, Segment 2/2: Too few valid points (7). Skipping segment.
# Well JE018, Segment 2/2: Too few valid points (22). Skipping segment.
# Well MY080, Segment 2/2: Too few valid points (13). Skipping segment.
# Well SY050, Segment 2/2: Too few valid points (2). Skipping segment.
# Well CM024, Segment 1/2: Too few valid points (23). Skipping segment.
# Well KT015, Segment 2/2: Too few valid points (32). Skipping segment.
# Well JE040, Segment 2/2: Too few valid points (15). Skipping segment.
# Well KH010, Segment 1/2: Too few valid points (44). Skipping segment.
# Well CT035, Segment 2/2: Too few valid points (1). Skipping segment.
# Well SY072, Segment 2/2: Too few valid points (18). Skipping segment.
# Well FA021, Segment 1/2: Too few valid points (52). Skipping segment.
# Well KT042, Segment 2/2: Too few valid points (7). Skipping segment.
# Well BA005, Segment 1/2: Too few valid points (21). Skipping segment.
# Well MY004, Segment 2/3: Too few valid points (6). Skipping segment.
# Well MY004, Segment 3/3: Too few valid points (17). Skipping segment.
# Well FA058, Segment 1/2: Too few valid points (53). Skipping segment.
# Well MY083, Segment 2/2: Too few valid points (57). Skipping segment.
# Well SY082, Segment 2/2: Too few valid points (17). Skipping segment.
# Well SY023, Segment 2/2: Too few valid points (36). Skipping segment.
# Well CM043, Segment 2/2: Too few valid points (5). Skipping segment.
# Well JE058, Segment 2/2: Too few valid points (1). Skipping segment.
# Well DH115, Segment 2/2: Too few valid points (36). Skipping segment.
# Well JE048, Segment 2/3: Too few valid points (6). Skipping segment.
# Well JE048, Segment 3/3: Too few valid points (1). Skipping segment.
# Well TA020, Segment 2/2: Too few valid points (26). Skipping segment.
# Well MY046, Segment 1/2: Too few valid points (35). Skipping segment.
# Well FS06, Segment 1/2: Too few valid points (31). Skipping segment.
# Well KT049, Segment 2/2: Too few valid points (22). Skipping segment.
# Well RA-26, Segment 1/2: Too few valid points (55). Skipping segment.
# Well CM013, Segment 2/2: Too few valid points (9). Skipping segment.
# Well CM020, Segment 2/2: Too few valid points (13). Skipping segment.
# Well CM031, Segment 2/2: Too few valid points (1). Skipping segment.
# Well KT007, Segment 2/2: Too few valid points (3). Skipping segment.
# Well SY030, Segment 2/2: Too few valid points (13). Skipping segment.
# Well DH124, Segment 1/2: Too few valid points (56). Skipping segment.
# Well PA040, Segment 1/2: Too few valid points (46). Skipping segment.
# Well SY069, Segment 2/2: Too few valid points (7). Skipping segment.
# Well NA012, Segment 2/2: Too few valid points (3). Skipping segment.
# Well KH022, Segment 3/3: Too few valid points (4). Skipping segment.
# Well DI084, Segment 1/2: Too few valid points (8). Skipping segment.
# Well DH090, Segment 1/2: Too few valid points (17). Skipping segment.
# Well RJ048, Segment 1/2: Too few valid points (48). Skipping segment.
# Well KT036, Segment 1/2: Too few valid points (39). Skipping segment.
# Well MY011, Segment 2/2: Too few valid points (33). Skipping segment.
# Well NA015, Segment 2/2: Too few valid points (18). Skipping segment.
# Well NA027, Segment 2/2: Too few valid points (4). Skipping segment.
# Well SY102, Segment 2/2: Too few valid points (5). Skipping segment.
# Well DH064, Segment 2/2: Too few valid points (49). Skipping segment.
# Well SY045, Segment 1/2: Too few valid points (51). Skipping segment.
# Well RJ105, Segment 2/2: Too few valid points (34). Skipping segment.
# Well KT034, Segment 2/2: Too few valid points (17). Skipping segment.
# Well CM029, Segment 2/2: Too few valid points (1). Skipping segment.
# Well JES16, Segment 2/2: Too few valid points (26). Skipping segment.
# Well SY083, Segment 2/2: Too few valid points (14). Skipping segment.
# Well CM036, Segment 2/2: Too few valid points (21). Skipping segment.
# Well SY061, Segment 1/2: Too few valid points (54). Skipping segment.
# Well JES17, Segment 2/2: Too few valid points (24). Skipping segment.
# Well RJ143, Segment 2/2: Too few valid points (25). Skipping segment.
# Well SY036, Segment 2/2: Too few valid points (14). Skipping segment.
# Well JES12, Segment 2/2: Too few valid points (8). Skipping segment.
# Well DH074, Segment 2/2: Too few valid points (34). Skipping segment.
# Well DI058A, Segment 2/2: Too few valid points (36). Skipping segment.
# Well JES11, Segment 2/2: Too few valid points (26). Skipping segment.
# Well JES08, Segment 2/2: Too few valid points (26). Skipping segment.
# Well CM040, Segment 2/2: Too few valid points (1). Skipping segment.
# Well MY007, Segment 2/2: Too few valid points (19). Skipping segment.
# Well DH121, Segment 1/2: Too few valid points (32). Skipping segment.
# Well NA005, Segment 2/3: Too few valid points (8). Skipping segment.
# Well NA005, Segment 3/3: Too few valid points (11). Skipping segment.
# Well CM054, Segment 2/2: Too few valid points (25). Skipping segment.
# Well SY015, Segment 2/2: Too few valid points (6). Skipping segment.
# Well DH086, Segment 2/2: Too few valid points (25). Skipping segment.
# Well CH001, Segment 2/2: Too few valid points (3). Skipping segment.
# Well KTS007, Segment 2/2: Too few valid points (21). Skipping segment.
# Well MY035, Segment 1/3: Too few valid points (16). Skipping segment.
# Well CM047, Segment 2/2: Too few valid points (21). Skipping segment.
# Well JES13, Segment 2/2: Too few valid points (24). Skipping segment.
# Well NA002, Segment 2/2: Too few valid points (12). Skipping segment.
# Well PAS07, Segment 2/2: Too few valid points (17). Skipping segment.
# Well CT040, Segment 1/3: Too few valid points (44). Skipping segment.
# Well CT040, Segment 3/3: Too few valid points (12). Skipping segment.
# Well CT052, Segment 2/2: Too few valid points (8). Skipping segment.
# Well FS01, Segment 1/2: Too few valid points (46). Skipping segment.
# handle manually: RJ027 | 2002-12-15 00:00:00
# Well RA-68, Segment 1/2: Too few valid points (52). Skipping segment.
# Well JES18, Segment 2/2: Too few valid points (1). Skipping segment.
# Well RA-25, Segment 1/2: Too few valid points (48). Skipping segment.
# Well CM012, Segment 1/2: Too few valid points (46). Skipping segment.
# Well MY048, Segment 2/2: Too few valid points (6). Skipping segment.
# Well KTS011, Segment 2/2: Too few valid points (22). Skipping segment.
# Well NA024, Segment 1/2: Too few valid points (37). Skipping segment.
# Well SY081, Segment 2/2: Too few valid points (22). Skipping segment.
# Well SY112, Segment 2/2: Too few valid points (2). Skipping segment.
# Well JE043, Segment 1/2: Too few valid points (12). Skipping segment.
# Well RA-55, Segment 1/2: Too few valid points (57). Skipping segment.
# Well CM003, Segment 2/2: Too few valid points (8). Skipping segment.
# Well NA026, Segment 2/2: Too few valid points (4). Skipping segment.
# Well JES19, Segment 2/3: Too few valid points (8). Skipping segment.
# Well JES19, Segment 3/3: Too few valid points (25). Skipping segment.
# Well FS05, Segment 1/2: Too few valid points (45). Skipping segment.
# Well FS02, Segment 1/2: Too few valid points (46). Skipping segment.
# Well PAS08, Segment 2/2: Too few valid points (17). Skipping segment.
# Well SY054, Segment 1/2: Too few valid points (15). Skipping segment.
# Well SY041, Segment 2/2: Too few valid points (1). Skipping segment.
# Well KT030, Segment 1/2: Too few valid points (17). Skipping segment.
# Well KTS004, Segment 2/3: Too few valid points (11). Skipping segment.
# Well KTS004, Segment 3/3: Too few valid points (20). Skipping segment.
# Well CH006, Segment 1/2: Too few valid points (55). Skipping segment.
# Well SY032, Segment 2/2: Too few valid points (7). Skipping segment.
# Well JA022, Segment 1/2: Too few valid points (26). Skipping segment.
# Well DH114, Segment 2/2: Too few valid points (26). Skipping segment.
# Well CT004, Segment 2/3: Too few valid points (1). Skipping segment.
# Well CT004, Segment 3/3: Too few valid points (2). Skipping segment.
# Well JE054, Segment 1/3: Too few valid points (58). Skipping segment.
# Well JE054, Segment 3/3: Too few valid points (1). Skipping segment.
# Well JES14, Segment 2/2: Too few valid points (12). Skipping segment.
# Well MY038, Segment 2/2: Too few valid points (29). Skipping segment.
# Well SY065, Segment 1/3: Too few valid points (42). Skipping segment.
# Well SY065, Segment 3/3: Too few valid points (1). Skipping segment.
# Well CT027, Segment 3/3: Too few valid points (17). Skipping segment.
# Well NA020, Segment 2/2: Too few valid points (1). Skipping segment.
# Well KT023, Segment 2/2: Too few valid points (17). Skipping segment.
# Well CM030, Segment 2/2: Too few valid points (18). Skipping segment.
# Well SY053, Segment 3/4: Too few valid points (32). Skipping segment.
# Well RJS08, Segment 2/2: Too few valid points (17). Skipping segment.
# Well RJS37, Segment 2/2: Too few valid points (16). Skipping segment.
# Well RJS35, Segment 2/2: Too few valid points (16). Skipping segment.
# Well RJS05, Segment 2/2: Too few valid points (18). Skipping segment.
# Well RJS11, Segment 2/2: Too few valid points (18). Skipping segment.
# Well DH101, Segment 2/3: Too few valid points (1). Skipping segment.
# Well DH101, Segment 3/3: Too few valid points (48). Skipping segment.
# Well CM053, Segment 2/2: Too few valid points (32). Skipping segment.
# Well CT010, Segment 2/2: Too few valid points (25). Skipping segment.
# Well CT033, Segment 2/2: Too few valid points (15). Skipping segment.
# Well RJS06, Segment 2/2: Too few valid points (16). Skipping segment.
# Well TA031, Segment 3/3: Too few valid points (6). Skipping segment.
# Well MY065, Segment 2/2: Too few valid points (52). Skipping segment.
# Well RJS29, Segment 2/3: Too few valid points (36). Skipping segment.
# Well RJS29, Segment 3/3: Too few valid points (10). Skipping segment.
# Well MY045, Segment 2/3: Too few valid points (40). Skipping segment.
# Well MY045, Segment 3/3: Too few valid points (25). Skipping segment.
# Well SY068, Segment 1/3: Too few valid points (31). Skipping segment.
# Well SY068, Segment 3/3: Too few valid points (1). Skipping segment.
# Well CT036, Segment 1/2: Too few valid points (37). Skipping segment.
# Well KH011, Segment 3/3: Too few valid points (22). Skipping segment.
# Well RA-72, Segment 1/2: Too few valid points (24). Skipping segment.
# Well FS03, Segment 1/2: Too few valid points (33). Skipping segment.
# Well PAS11, Segment 2/2: Too few valid points (17). Skipping segment.
# Well BA006, Segment 2/3: Too few valid points (49). Skipping segment.
# Well BA006, Segment 3/3: Too few valid points (3). Skipping segment.
# Well RJS07, Segment 2/2: Too few valid points (17). Skipping segment.
# Well CT053, Segment 1/2: Too few valid points (28). Skipping segment.
# Well KTS012, Segment 2/2: Too few valid points (9). Skipping segment.
# Well RJS13, Segment 2/2: Too few valid points (17). Skipping segment.
# Well PAS10, Segment 2/2: Too few valid points (16). Skipping segment.
# Well CT019, Segment 3/3: Too few valid points (12). Skipping segment.
# Well SY093, Segment 3/3: Too few valid points (29). Skipping segment.
# Well CM041, Segment 2/2: Too few valid points (2). Skipping segment.
# Well CM027, Segment 2/4: Too few valid points (37). Skipping segment.
# Well CM027, Segment 3/4: Too few valid points (11). Skipping segment.
# Well CM027, Segment 4/4: Too few valid points (3). Skipping segment.
# Well CM050, Segment 2/3: Too few valid points (46). Skipping segment.
# Well CM050, Segment 3/3: Too few valid points (4). Skipping segment.
# Well RJS33, Segment 2/2: Too few valid points (13). Skipping segment.
# Well DH008, Segment 1/4: Too few valid points (46). Skipping segment.
# Well DH008, Segment 2/4: Too few valid points (8). Skipping segment.
# Well CM039, Segment 2/2: Too few valid points (2). Skipping segment.
# Well RJS18, Segment 2/3: Too few valid points (47). Skipping segment.
# Well RJS18, Segment 3/3: Too few valid points (16). Skipping segment.
# Well JES04, Segment 2/2: Too few valid points (2). Skipping segment.
# Well JA017, Segment 1/2: Too few valid points (22). Skipping segment.
# Well JE022, Segment 1/3: Too few valid points (38). Skipping segment.
# Well JE022, Segment 3/3: Too few valid points (2). Skipping segment.
# Well CM037, Segment 2/3: Too few valid points (41). Skipping segment.
# Well CM037, Segment 3/3: Too few valid points (3). Skipping segment.
# Well RJS38, Segment 2/2: Too few valid points (16). Skipping segment.
# Well KTS005, Segment 2/2: Too few valid points (12). Skipping segment.
# Well KTS014, Segment 3/3: Too few valid points (22). Skipping segment.
# Well CH004, Segment 2/2: Too few valid points (2). Skipping segment.
# Well MY057, Segment 2/2: Too few valid points (15). Skipping segment.
# Well RJS03, Segment 2/2: Too few valid points (17). Skipping segment.
# Well KHS03, Segment 1/2: Too few valid points (47). Skipping segment.
# Well DH098, Segment 1/2: Too few valid points (13). Skipping segment.
# Well CT013, Segment 1/2: Too few valid points (52). Skipping segment.
# Well BA028, Segment 1/3: Too few valid points (23). Skipping segment.
# Well BA028, Segment 3/3: Too few valid points (7). Skipping segment.
# Well PA050, Segment 2/3: Too few valid points (2). Skipping segment.
# handle manually: PA050 | 2005-04-15 00:00:00
# handle manually: PA050 | 2007-10-15 00:00:00
# Well CM046, Segment 2/3: Too few valid points (22). Skipping segment.
# Well CM046, Segment 3/3: Too few valid points (13). Skipping segment.
# Well SY049, Segment 2/3: Too few valid points (5). Skipping segment.
# Well SY049, Segment 3/3: Too few valid points (1). Skipping segment.
# Well DH070, Segment 2/2: Too few valid points (6). Skipping segment.
# Well BA020, Segment 3/3: Too few valid points (46). Skipping segment.
# Well KT052, Segment 2/3: Too few valid points (24). Skipping segment.
# Well RJ017, Segment 2/3: Too few valid points (27). Skipping segment.
# Well JES15, Segment 2/3: Too few valid points (10). Skipping segment.
# Well JES15, Segment 3/3: Too few valid points (24). Skipping segment.
# Well RJS23, Segment 2/2: Too few valid points (5). Skipping segment.
# Well KTS019, Segment 2/2: Too few valid points (9). Skipping segment.
# Well CH010, Segment 1/2: Too few valid points (54). Skipping segment.
# Well PAS12, Segment 2/2: Too few valid points (15). Skipping segment.
# Well PAS13, Segment 2/2: Too few valid points (16). Skipping segment.
# Well SY090, Segment 2/2: Too few valid points (1). Skipping segment.
# Well NA014, Segment 3/3: Too few valid points (2). Skipping segment.
# Well CT044, Segment 2/3: Too few valid points (14). Skipping segment.
# Well CT044, Segment 3/3: Too few valid points (22). Skipping segment.
# Well RJS16, Segment 2/3: Too few valid points (42). Skipping segment.
# Well RJS16, Segment 3/3: Too few valid points (18). Skipping segment.
# Well MY028, Segment 1/3: Too few valid points (38). Skipping segment.
# Well MY028, Segment 3/3: Too few valid points (15). Skipping segment.
# handle manually: MY039 | 1993-10-15 00:00:00
# Well MY039, Segment 3/3: Too few valid points (48). Skipping segment.
# Well CT016, Segment 3/3: Too few valid points (5). Skipping segment.
# Well NA025, Segment 2/2: Too few valid points (2). Skipping segment.
# Well CM056, Segment 2/2: Too few valid points (3). Skipping segment.
# Well SY077, Segment 2/3: Too few valid points (24). Skipping segment.
# Well SY077, Segment 3/3: Too few valid points (11). Skipping segment.
# Well JES007, Segment 2/2: Too few valid points (25). Skipping segment.
# Well SY007, Segment 3/4: Too few valid points (41). Skipping segment.
# Well SY007, Segment 4/4: Too few valid points (2). Skipping segment.
# Well RJS14, Segment 2/3: Too few valid points (40). Skipping segment.
# Well RJS14, Segment 3/3: Too few valid points (16). Skipping segment.
# Well PAS03, Segment 3/3: Too few valid points (17). Skipping segment.
# Well SY086, Segment 3/3: Too few valid points (1). Skipping segment.
# Well CM017, Segment 1/2: Too few valid points (48). Skipping segment.
# Well SY066, Segment 1/3: Too few valid points (32). Skipping segment.
# Well SY066, Segment 3/3: Too few valid points (5). Skipping segment.
# Well CT029, Segment 3/3: Too few valid points (8). Skipping segment.
# Well CT045, Segment 2/4: Too few valid points (48). Skipping segment.
# Well CT045, Segment 3/4: Too few valid points (44). Skipping segment.
# Well CT045, Segment 4/4: Too few valid points (39). Skipping segment.
# Well MY082, Segment 1/3: Too few valid points (57). Skipping segment.
# Well MY082, Segment 3/3: Too few valid points (4). Skipping segment.
# Well KH014, Segment 1/3: Too few valid points (31). Skipping segment.
# Well KH014, Segment 2/3: Too few valid points (39). Skipping segment.
# Well PAS06, Segment 3/3: Too few valid points (17). Skipping segment.
# Well SY084, Segment 2/3: Too few valid points (2). Skipping segment.
# Well SY084, Segment 3/3: Too few valid points (39). Skipping segment.
# Well RJ059, Segment 1/5: Too few valid points (30). Skipping segment.
# Well RJ059, Segment 2/5: Too few valid points (6). Skipping segment.
# Well RJ059, Segment 3/5: Too few valid points (3). Skipping segment.
# Well MY033, Segment 3/3: Too few valid points (54). Skipping segment.
# Processing finished.
# Generated 1630 processed time series segments.

# %% [markdown]
# #### 3. Manual quality control
# stitch, split, remove

# %%
### manual outlier removal
def remove_outliers_manually(mask, well):
    ts_file_bgl.loc[mask, well] = np.nan
    ts_file_gwl.loc[mask, well] = np.nan
    ts_file_gws.loc[mask, well] = np.nan

min_out = { 
    'RJ002_1': -14, 'RJ007': -12, 'SY057': -4, 'RJ061': -10, 'RJ080': -11, 'MY005': -5, 'MY020': -8, 'MY030': -12, 'CM028': -3.5, 'DH085': -6,
    'DH083': -6, 'RA-53': -6, 'KT039': -12, 'RA-50': -5, 'MY071': -6.5, 'KH016': -3.5, 'RJ127': -20, 'KH012': -3, 'BO022': -8.5, 'SY105': -6, 'MY013': -6,
    'JA015': -7, 'MY080_1': -8, 'PA061': -8, 'DH004': -12, 'DH091_1': -9, 'PT007': -1.4, 'RJ110': -9, 'RJ141_1': -10, 'NA024_2_0': -4.7,
    'SY025_1': -4.5, 'PA055_2': -12, 'RJ126_1': -3, 'BA030_1': -1, 'RJS23_1_0': -8
}

for well, threshold in min_out.items():
    mask = ts_file_bgl[ts_file_bgl[well] < threshold].index
    remove_outliers_manually(mask, well)

min_out_constr = {'RA-44': ['1990-01-01', -4], 'SY112_1': ['1990-01-01', -3], 'DH057_0': ['1990-01-01', -4],
                 'PT009_1': ['2008-01-01', -0.5]}

for well, (s_date, threshold) in min_out_constr.items():
    mask = ts_file_bgl[ts_file_bgl[well] < threshold][:s_date].index
    remove_outliers_manually(mask, well)

max_out_constr = {'DH015_1': ['2010-01-01', -63], 'CT008': ['2005-01-01', 1], 'KH020': ['1980-01-01', -0.8], 'KH021': ['1980-01-01', -0.8],
                  'DH002_0': ['2010-01-01', -18], 'SY072_1_0': ['1990-01-01', -1], 'SY040_1': ['2015-01-01', -10], 'CT013_2_1': ['1992-01-01', -2], 
                  'DI030': ['1993-01-01', -0.2], 'SY068_2_1': ['1988-01-01', -0.5], 'SY044_0': ['1987-01-01',-2], 'SY035_1': ['1985-01-01', -0.5], 
                  'RJ105_1_0': ['1992-01-01', -9], 'RA-30_3': ['2010-01-01', -2], 'SY031_1_1': ['1990-01-01', 0], 'RJS29_1_2': ['1994-01-01', -10]
                 }

for well, (s_date, threshold) in max_out_constr.items():
    mask = ts_file_bgl[ts_file_bgl[well] > threshold][s_date:].index
    remove_outliers_manually(mask, well)

remove_range = {'FA058_2': ['1998-01-01', '2002-01-01'],
               'CT004_1': ['1982-06-01', '1985-01-01'] }

for well, (s_date, e_date) in remove_range.items():
    mask = ts_file_bgl[well][s_date:e_date].index
    remove_outliers_manually(mask, well)

# %%
# # stitching
stitch_ids = ['SY075', 'RJ013', 'BO029', 'RJ092', 'MY073', 'KT047', 'CT011', 'RJ106', 
              'MY030', 'RJ142', 'SY056', 'BO005', 'RJ002', 'RJ005', 'KT010', 'CT034', 
              'JA024', 'RJ015', 'JE036', 'RJ006', 'JE020', 'JE046', 'RA-16', 'BO009', 
              'CM006', 'KH009', 'JES08', 'JES11', 'RA-01', 'RJ008', 'JE013', 'BO010',
              'BO007', 'MY012', 'MY024', 'JE029', 'KT037', 'KT008', 'PA016', 'TA026',
              'RJ104', 'RJ089', 'BA009', 'DI057', 'PA009', 'RJ045', 'RJ014', 'CM010',
              'FA035', 'KH006', 'DI041', 'JE045', 'CT014', 'RA-49', 'MY084', 'DI091',
              'KT015', 'JA002', 'RJ141', 'RJ125', 'DH096', 'RJ133', 'KT046', 'FA033',
              'FA064', 'DH127', 'SY074', 'PA012', 'RA-36', 'DI019', 'DH110', 'SY093',
              'CT029', 'CT037', 'BO038', 'DI058', 'RA-66', 'RJ058', 'KT027', 'KT048',
              'RJ009', 'SY011', 'RJ081', 'RJ043', 'RJ122', 'RJ075', 'PA004', 'SY078',
              'RJ087', 'RJ032', 'DI048', 'DH015', 'KT004', 'JE060', 'RJ131', 'DH087',
              'RJ116', 'SY076', 'RJ139', 'BA029', 'NA018', 'DH091', 'TA003', 'DI055',
              'RJ012', 'JE050', 'JA009', 'SY018', 'KT028', 'CM059', 'MY043', 'SY045',
              'DH065', 'CM063', 'FA033', 'RJ027', 'SY099', 'RA-75', 'BA016', 'SY094',
              'CT027', 'TA031', 'KH011', 'SY097', 'PAS03', 'DI030']

for stitch_id in stitch_ids:
    parts_bgl = ts_file_bgl.filter(like=stitch_id, axis=1)
    parts_gwl = ts_file_gwl.filter(like=stitch_id, axis=1)
    parts_gws = ts_file_gws.filter(like=stitch_id, axis=1)

    ts_file_bgl = ts_file_bgl.drop(parts_bgl.columns, axis=1)
    ts_file_gwl = ts_file_gwl.drop(parts_gwl.columns, axis=1)
    ts_file_gws = ts_file_gws.drop(parts_gws.columns, axis=1)

    ts_file_bgl[stitch_id] = parts_bgl.bfill(axis=1).iloc[:, 0]
    ts_file_gwl[stitch_id] = parts_gwl.bfill(axis=1).iloc[:, 0]
    ts_file_gws[stitch_id] = parts_gws.bfill(axis=1).iloc[:, 0]

# stitching 2 first parts
stitch2_ids = ['PA020', 'DI051', 'SY055', 'SY048', 'CT022', 'NA006', 'RJ076']
for stitch2_id in stitch2_ids:
    parts_bgl = ts_file_bgl.filter(like=stitch2_id, axis=1).iloc[:,:2]
    parts_gwl = ts_file_gwl.filter(like=stitch2_id, axis=1).iloc[:,:2]
    parts_gws = ts_file_gws.filter(like=stitch2_id, axis=1).iloc[:,:2]
    
    ts_file_bgl = ts_file_bgl.drop(parts_bgl.columns, axis=1)
    ts_file_gwl = ts_file_gwl.drop(parts_gwl.columns, axis=1)
    ts_file_gws = ts_file_gws.drop(parts_gws.columns, axis=1)

    print(stitch2_id)
    ts_file_bgl[f'{stitch2_id}_1'] = parts_bgl.bfill(axis=1).iloc[:, 0]
    ts_file_gwl[f'{stitch2_id}_1'] = parts_gwl.bfill(axis=1).iloc[:, 0]
    ts_file_gws[f'{stitch2_id}_1'] = parts_gws.bfill(axis=1).iloc[:, 0]

# stitching 2 last parts
stitch2_ids = ['KT053', 'RJ098', 'JA004', 'RJ073', 'SY014', 'SY104']
for stitch2_id in stitch2_ids:
    parts_bgl = ts_file_bgl.filter(like=stitch2_id, axis=1).iloc[:,1:]
    parts_gwl = ts_file_gwl.filter(like=stitch2_id, axis=1).iloc[:,1:]
    parts_gws = ts_file_gws.filter(like=stitch2_id, axis=1).iloc[:,1:]
    
    ts_file_bgl = ts_file_bgl.drop(parts_bgl.columns, axis=1)
    ts_file_gwl = ts_file_gwl.drop(parts_gwl.columns, axis=1)
    ts_file_gws = ts_file_gws.drop(parts_gws.columns, axis=1)

    print(stitch2_id)
    ts_file_bgl[f'{stitch2_id}_1'] = parts_bgl.bfill(axis=1).iloc[:, 0]
    ts_file_gwl[f'{stitch2_id}_1'] = parts_gwl.bfill(axis=1).iloc[:, 0]
    ts_file_gws[f'{stitch2_id}_1'] = parts_gws.bfill(axis=1).iloc[:, 0]


# splitting
split_ids = ['RJ031_0', 'DH001', 'SY078', 'SY027', 'RJ142', 'CM036_1', 'SY046_0', 'MY023_1', 
             'SY010', 'MY016', 'DI046_2', 'PA028', 'RJ102', 'RJ006', 'CM062', 'DH079', 'KT007_1',
             'DH090_2', 'KT034_1', 'PA018','TA033_0', 'FA007', 'DI008', 'BA021', 'DI033',
             'KT022', 'FA013', 'RJ077', 'DI042','DH069', 'JE030', 'RJ009', 'RJ033', 'MY087', 
             'RJ044', 'FA008', 'BA001', 'KT001', 'CT005', 'RJ103', 'JE017', 'RJ069', 'RJ068', 
             'PA011_0', 'JE015', 'CM057', 'RJ081', 'SY008', 'TA029', 'BA008_1', 'BA013_2', 
             'KH002_1', 'CT003_0', 'RJ088', 'DH076', 'MY051', 'BO035', 'FA004', 'BO027_1',
             'DI030', 'KT020', 'JE046', 'KH004', 'RA-43', 'DI076', 'MY018', 'KT029', 'DH073',
             'MY079', 'BO026', 'CT011', 'SY011', 'KH009', 'PA012', 'KT041', 'BO020',
             'MY073', 'CM016_1', 'BO006', 'PA031', 'MY053_1', 'JE039', 'SY055_1', 'DH005',
             'KHCP03', 'NA023_0', 'RJ029', 'BA005_2', 'MY074','NA015_1', 'CT004_1', 'RJ076_1']

split_dates = ['2010-01-01', '2012-01-01', '2007-01-01', '1984-01-01', '1992-01-01',
               '2001-01-01', '1992-01-01', '1990-01-01', '1985-01-01', '1991-01-01', 
               '1989-01-01', '2007-01-01', '1993-01-01', '1993-01-01', '1988-01-01', 
               '1991-06-01', '1982-01-01', '1990-01-01', '1989-01-01', '1986-01-01', 
               '1993-06-01', '1986-01-01', '1991-01-01', '1998-01-01', '1986-01-01', 
               '1993-01-01', '1983-01-01', '1986-06-01', '1992-01-01', '1990-01-01', 
               '1993-06-01', '1992-06-01', '1992-06-01', '1991-01-01', '1983-06-01', 
               '1986-06-01', '1985-01-01', '1987-01-01', '1986-06-01', '1992-01-01',
               '1991-01-01', '1982-06-01', '1992-06-01', '1992-01-01', '1984-01-01',
               '1990-06-01', '1992-01-01', '1986-06-01', '1984-06-01', '1992-01-01', 
               '1992-01-01', '1990-01-01', '1985-06-01', '1992-01-01', '1990-06-01', 
               '1987-06-01', '1987-01-01', '1986-01-01', '1989-01-01', '1993-01-01', 
               '1987-01-01', '2002-01-01', '1987-06-01', '1993-01-01', '1992-06-01',
               '1992-01-01', '1991-06-01', '1985-06-01', '1992-01-01', '1991-01-01',
               '1989-06-01', '1984-06-01', '1985-01-01', '1990-01-01', '1992-01-01',
               '1988-01-01', '1979-01-01', '1975-01-01', '2012-01-01', '1987-01-01',
               '1985-01-01', '1991-01-01', '2000-01-01', '1991-01-01', '1991-01-01',
               '2003-01-01', '1988-01-01', '2005-01-01', '2005-01-01', '1991-01-01', 
               '1988-01-01', '1991-01-01']

for i, split_id in enumerate(split_ids):
    entry_bgl = ts_file_bgl[split_id]
    entry_gwl = ts_file_gwl[split_id]
    entry_gws = ts_file_gws[split_id]
    ts_file_bgl = ts_file_bgl.drop(split_id, axis=1)
    ts_file_gwl = ts_file_gwl.drop(split_id, axis=1)
    ts_file_gws = ts_file_gws.drop(split_id, axis=1)
    
    mask = entry_bgl.index < split_dates[i]

    if split_id in ['MY073', 'CM016_1']:
        mask = entry_bgl.index > split_dates[i]

    if split_id in ['SY027', 'RJ142', 'SY046_0', 'MY023_1', 'SY010', 'MY016', 
                    'DI046_2', 'PA028', 'RJ102', 'RJ006', 'CM062', 'DH079', 'KT007_1', 
                    'DH090_2', 'KT034_1', 'PA018', 'TA033_0', 'FA007', 'DI008', 'BA021', 'DI033',
                    'KT022', 'FA013', 'RJ077', 'DI042', 'DH069', 'JE030', 'RJ009', 'RJ033', 'MY087',
                    'RJ044', 'FA008', 'BA001', 'KT001', 'CT005', 'RJ103', 'JE017', 'RJ069',
                    'RJ068', 'PA011_0', 'JE015', 'CM057', 'RJ081', 'SY008', 'TA029', 'BA008_1',
                    'BA013_2', 'KH002_1', 'CT003_0', 'RJ088', 'DH076', 'MY051', 'BO035', 'FA004',
                    'BO027_1', 'DI030', 'KT020', 'KH004', 'RA-43',
                    'DI076', 'MY018', 'KT029', 'DH073', 'MY079', 'BO026', 'CT011', 'SY011',
                    'KH009', 'PA012', 'KT041', 'BO020', 'BO006', 'PA031', 'MY053_1', 'JE039',
                    'SY055_1', 'DH005', 'RJ029', 'BA005_2', 'NA015_1', 'CT004', 'RJ076_1']:
        ts_file_bgl[f'{split_id}_0'] = entry_bgl.where(mask)
        ts_file_gwl[f'{split_id}_0'] = entry_gwl.where(mask)
        ts_file_gws[f'{split_id}_0'] = entry_gws.where(mask)
        ts_file_bgl[f'{split_id}_1'] = entry_bgl.where(~mask)
        ts_file_gwl[f'{split_id}_1'] = entry_gwl.where(~mask)
        ts_file_gws[f'{split_id}_1'] = entry_gws.where(~mask)
    else:
        ts_file_bgl[f'{split_id}'] = entry_bgl.where(mask)
        ts_file_gwl[f'{split_id}'] = entry_gwl.where(mask)
        ts_file_gws[f'{split_id}'] = entry_gws.where(mask)

# removing
del_ids = ['DH124S', 'KT031_1']
for del_id in del_ids:
    ts_file_bgl = ts_file_bgl.drop(del_id, axis=1)
    ts_file_gwl = ts_file_gwl.drop(del_id, axis=1)
    ts_file_gws = ts_file_gws.drop(del_id, axis=1)
# Out:
# /tmp/ipykernel_49139/3232304779.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[stitch_id] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[stitch_id] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[stitch_id] = parts_gws.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[stitch_id] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[stitch_id] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[stitch_id] = parts_gws.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[stitch_id] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[stitch_id] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[stitch_id] = parts_gws.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[stitch_id] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[stitch_id] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[stitch_id] = parts_gws.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[stitch_id] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[stitch_id] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[stitch_id] = parts_gws.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[stitch_id] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[stitch_id] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[stitch_id] = parts_gws.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[stitch_id] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[stitch_id] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[stitch_id] = parts_gws.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[stitch_id] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[stitch_id] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[stitch_id] = parts_gws.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[stitch_id] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[stitch_id] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[stitch_id] = parts_gws.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[stitch_id] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[stitch_id] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[stitch_id] = parts_gws.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[stitch_id] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[stitch_id] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[stitch_id] = parts_gws.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[stitch_id] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[stitch_id] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[stitch_id] = parts_gws.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[stitch_id] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[stitch_id] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[stitch_id] = parts_gws.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[stitch_id] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[stitch_id] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[stitch_id] = parts_gws.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[stitch_id] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[stitch_id] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[stitch_id] = parts_gws.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[stitch_id] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[stitch_id] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[stitch_id] = parts_gws.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[stitch_id] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[stitch_id] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[stitch_id] = parts_gws.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[stitch_id] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[stitch_id] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[stitch_id] = parts_gws.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[stitch_id] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[stitch_id] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[stitch_id] = parts_gws.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[stitch_id] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[stitch_id] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[stitch_id] = parts_gws.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[stitch_id] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[stitch_id] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[stitch_id] = parts_gws.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[stitch_id] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[stitch_id] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[stitch_id] = parts_gws.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[stitch_id] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[stitch_id] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[stitch_id] = parts_gws.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[stitch_id] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[stitch_id] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[stitch_id] = parts_gws.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[stitch_id] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[stitch_id] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[stitch_id] = parts_gws.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[stitch_id] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[stitch_id] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[stitch_id] = parts_gws.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[stitch_id] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[stitch_id] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[stitch_id] = parts_gws.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[f'{stitch2_id}_1'] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[f'{stitch2_id}_1'] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[f'{stitch2_id}_1'] = parts_gws.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[f'{stitch2_id}_1'] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[f'{stitch2_id}_1'] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[f'{stitch2_id}_1'] = parts_gws.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[f'{stitch2_id}_1'] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[f'{stitch2_id}_1'] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[f'{stitch2_id}_1'] = parts_gws.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[f'{stitch2_id}_1'] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[f'{stitch2_id}_1'] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[f'{stitch2_id}_1'] = parts_gws.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[f'{stitch2_id}_1'] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[f'{stitch2_id}_1'] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[f'{stitch2_id}_1'] = parts_gws.bfill(axis=1).iloc[:, 0]
# PA020
# DI051
# SY055
# SY048
# CT022
# NA006
# RJ076
# KT053
# /tmp/ipykernel_49139/3232304779.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[f'{stitch2_id}_1'] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[f'{stitch2_id}_1'] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[f'{stitch2_id}_1'] = parts_gws.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[f'{stitch2_id}_1'] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[f'{stitch2_id}_1'] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[f'{stitch2_id}_1'] = parts_gws.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[f'{stitch2_id}_1'] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[f'{stitch2_id}_1'] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[f'{stitch2_id}_1'] = parts_gws.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[f'{stitch2_id}_1'] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[f'{stitch2_id}_1'] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[f'{stitch2_id}_1'] = parts_gws.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[f'{stitch2_id}_1'] = parts_bgl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[f'{stitch2_id}_1'] = parts_gwl.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[f'{stitch2_id}_1'] = parts_gws.bfill(axis=1).iloc[:, 0]
# /tmp/ipykernel_49139/3232304779.py:129: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[f'{split_id}'] = entry_bgl.where(mask)
# /tmp/ipykernel_49139/3232304779.py:130: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[f'{split_id}'] = entry_gwl.where(mask)
# /tmp/ipykernel_49139/3232304779.py:131: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[f'{split_id}'] = entry_gws.where(mask)
# /tmp/ipykernel_49139/3232304779.py:129: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[f'{split_id}'] = entry_bgl.where(mask)
# /tmp/ipykernel_49139/3232304779.py:130: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[f'{split_id}'] = entry_gwl.where(mask)
# /tmp/ipykernel_49139/3232304779.py:131: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[f'{split_id}'] = entry_gws.where(mask)
# /tmp/ipykernel_49139/3232304779.py:129: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[f'{split_id}'] = entry_bgl.where(mask)
# /tmp/ipykernel_49139/3232304779.py:130: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[f'{split_id}'] = entry_gwl.where(mask)
# /tmp/ipykernel_49139/3232304779.py:131: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[f'{split_id}'] = entry_gws.where(mask)
# /tmp/ipykernel_49139/3232304779.py:122: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[f'{split_id}_0'] = entry_bgl.where(mask)
# /tmp/ipykernel_49139/3232304779.py:123: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[f'{split_id}_0'] = entry_gwl.where(mask)
# /tmp/ipykernel_49139/3232304779.py:124: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[f'{split_id}_0'] = entry_gws.where(mask)
# /tmp/ipykernel_49139/3232304779.py:125: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[f'{split_id}_1'] = entry_bgl.where(~mask)
# /tmp/ipykernel_49139/3232304779.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[f'{split_id}_1'] = entry_gwl.where(~mask)
# /tmp/ipykernel_49139/3232304779.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[f'{split_id}_1'] = entry_gws.where(~mask)
# ...
# /tmp/ipykernel_49139/3232304779.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[f'{split_id}_1'] = entry_gws.where(~mask)
# /tmp/ipykernel_49139/3232304779.py:122: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[f'{split_id}_0'] = entry_bgl.where(mask)
# /tmp/ipykernel_49139/3232304779.py:123: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[f'{split_id}_0'] = entry_gwl.where(mask)
# /tmp/ipykernel_49139/3232304779.py:124: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[f'{split_id}_0'] = entry_gws.where(mask)
# /tmp/ipykernel_49139/3232304779.py:125: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[f'{split_id}_1'] = entry_bgl.where(~mask)
# /tmp/ipykernel_49139/3232304779.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[f'{split_id}_1'] = entry_gwl.where(~mask)
# /tmp/ipykernel_49139/3232304779.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[f'{split_id}_1'] = entry_gws.where(~mask)
# /tmp/ipykernel_49139/3232304779.py:129: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[f'{split_id}'] = entry_bgl.where(mask)
# /tmp/ipykernel_49139/3232304779.py:130: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[f'{split_id}'] = entry_gwl.where(mask)
# /tmp/ipykernel_49139/3232304779.py:131: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[f'{split_id}'] = entry_gws.where(mask)
# /tmp/ipykernel_49139/3232304779.py:129: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[f'{split_id}'] = entry_bgl.where(mask)
# /tmp/ipykernel_49139/3232304779.py:130: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[f'{split_id}'] = entry_gwl.where(mask)
# /tmp/ipykernel_49139/3232304779.py:131: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[f'{split_id}'] = entry_gws.where(mask)
# /tmp/ipykernel_49139/3232304779.py:122: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[f'{split_id}_0'] = entry_bgl.where(mask)
# /tmp/ipykernel_49139/3232304779.py:123: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[f'{split_id}_0'] = entry_gwl.where(mask)
# /tmp/ipykernel_49139/3232304779.py:124: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[f'{split_id}_0'] = entry_gws.where(mask)
# /tmp/ipykernel_49139/3232304779.py:125: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[f'{split_id}_1'] = entry_bgl.where(~mask)
# /tmp/ipykernel_49139/3232304779.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[f'{split_id}_1'] = entry_gwl.where(~mask)
# /tmp/ipykernel_49139/3232304779.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[f'{split_id}_1'] = entry_gws.where(~mask)
# /tmp/ipykernel_49139/3232304779.py:122: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[f'{split_id}_0'] = entry_bgl.where(mask)
# /tmp/ipykernel_49139/3232304779.py:123: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[f'{split_id}_0'] = entry_gwl.where(mask)
# /tmp/ipykernel_49139/3232304779.py:124: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[f'{split_id}_0'] = entry_gws.where(mask)
# /tmp/ipykernel_49139/3232304779.py:125: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[f'{split_id}_1'] = entry_bgl.where(~mask)
# /tmp/ipykernel_49139/3232304779.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[f'{split_id}_1'] = entry_gwl.where(~mask)
# /tmp/ipykernel_49139/3232304779.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[f'{split_id}_1'] = entry_gws.where(~mask)
# /tmp/ipykernel_49139/3232304779.py:129: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[f'{split_id}'] = entry_bgl.where(mask)
# /tmp/ipykernel_49139/3232304779.py:130: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[f'{split_id}'] = entry_gwl.where(mask)
# /tmp/ipykernel_49139/3232304779.py:131: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[f'{split_id}'] = entry_gws.where(mask)
# /tmp/ipykernel_49139/3232304779.py:122: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[f'{split_id}_0'] = entry_bgl.where(mask)
# /tmp/ipykernel_49139/3232304779.py:123: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[f'{split_id}_0'] = entry_gwl.where(mask)
# /tmp/ipykernel_49139/3232304779.py:124: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[f'{split_id}_0'] = entry_gws.where(mask)
# /tmp/ipykernel_49139/3232304779.py:125: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[f'{split_id}_1'] = entry_bgl.where(~mask)
# /tmp/ipykernel_49139/3232304779.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[f'{split_id}_1'] = entry_gwl.where(~mask)
# /tmp/ipykernel_49139/3232304779.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[f'{split_id}_1'] = entry_gws.where(~mask)
# /tmp/ipykernel_49139/3232304779.py:129: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[f'{split_id}'] = entry_bgl.where(mask)
# /tmp/ipykernel_49139/3232304779.py:130: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[f'{split_id}'] = entry_gwl.where(mask)
# /tmp/ipykernel_49139/3232304779.py:131: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[f'{split_id}'] = entry_gws.where(mask)
# /tmp/ipykernel_49139/3232304779.py:122: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[f'{split_id}_0'] = entry_bgl.where(mask)
# /tmp/ipykernel_49139/3232304779.py:123: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[f'{split_id}_0'] = entry_gwl.where(mask)
# /tmp/ipykernel_49139/3232304779.py:124: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[f'{split_id}_0'] = entry_gws.where(mask)
# /tmp/ipykernel_49139/3232304779.py:125: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_bgl[f'{split_id}_1'] = entry_bgl.where(~mask)
# /tmp/ipykernel_49139/3232304779.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gwl[f'{split_id}_1'] = entry_gwl.where(~mask)
# /tmp/ipykernel_49139/3232304779.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ts_file_gws[f'{split_id}_1'] = entry_gws.where(~mask)

# %% [markdown]
# #### 4. Save preprocessed time series

# %%
ts_file_gws.to_csv(f'{root_path}/target/filtered_gws_ts_data_1961_2019.csv')
ts_file_gwl.to_csv(f'{root_path}/target/filtered_gwl_ts_data_1961_2019.csv')
ts_file_bgl.to_csv(f'{root_path}/target/filtered_bgl_ts_data_1961_2019.csv')
